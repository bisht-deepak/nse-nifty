# %%
{"ACC": "cement and cement products", "ADANIENT": "trading-minerals/ mining", "ADANIPORTS": "shipping, port and port services", 
 "AMBUJACEM": "cement and cement products", "AXISBANK": "banks", "BAJAJAUTO": "automobiles- 2 and 3 wheelers",
 "BAJFINANCE": "nbfc", "BEL": "aerospace and defence", "BHARTIARTL": "telecom", "BPCL": "refineries", "BRITANNIA": "food and food processing", "CAIRN": "oil and gas sector",
 "COALINDIA"}
